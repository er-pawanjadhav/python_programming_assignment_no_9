# %%
a= int(input("enter a no : "))
temp = a
b=len(str(a))
c=b
d=0
for i in range(b):
    r=a%10
    c=c-i
    d=d+r**c
    a=a//10

if temp ==d:
    print(f"this is diarium number")
else:
    print(f"this is not diarium number")
# Out:
# enter a no : 89
# this is diarium number
