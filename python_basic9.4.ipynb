# %%
def happy(a):
    c=0
    
    while a>0:
        r= a%10
        r=r*r
        c=c+r
        a = a//10
        if c==1:
            return c
            
            break
        elif c==t:
            return nothappy
            break
        elif a==0:
            a=c
            c=0
    
    
d=[]
for i in range(1,100):
    t = happy(i)
    if type(i)==str:
        d.append(t)

for j in d:
    print(j ,end= ' ')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-934687af28cb> in <module>
#      21 d=[]
#      22 for i in range(1,100):
# ---> 23     t = happy(i)
#      24     if type(i)==str:
#      25         d.append(t)
#
# <ipython-input-2-934687af28cb> in happy(a)
#       5         r= a%10
#       6         r=r*r
# ----> 7         c=c+r
#       8         a = a//10
#       9         if c==1:
#
# KeyboardInterrupt:

# %%
def happy(a):
    c=0
    
    while a>0:
        r= a%10
        r=r*r
        c=c+r
        a = a//10
    return c

d =[] 
for a in range(1,100):
    r = a
    t = a

    while r!=1 and r!=4:
        r = happy(r)

    if r==1:
        d.append(t)
    else:
        pass
print(d)
# Out:
# [1, 7, 10, 13, 19, 23, 28, 31, 32, 44, 49, 68, 70, 79, 82, 86, 91, 94, 97]
